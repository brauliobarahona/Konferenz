# %%
import numpy as np

# %%
img_array = np.load("../data/test/images/Flug1_105/DJI_0186_R.npy")

# %%
from matplotlib import pyplot as plt

plt.imshow(img_array[:,:,:3], cmap='gray')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.imshow(img_array[:,:,4], cmap='gray')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.imshow(img_array[:,:,0], cmap='gray')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.imshow(img_array[:,:,3], cmap='gray')
plt.show()
